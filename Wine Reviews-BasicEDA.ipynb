# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import seaborn as sns 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# load data
reviews_150k = pd.read_csv("../input/wine-reviews/winemag-data_first150k.csv")
reviews_130k = pd.read_csv("../input//wine-reviews/winemag-data-130k-v2.csv")

# %%
print(reviews_150k.shape)
reviews_150k.info()

# %%
reviews_150k

# %%
print(reviews_130k.shape)
reviews_130k.info()

# %%
reviews_130k

# %%
# 두 dataframe 값 비교

reviews = pd.concat([reviews_150k,reviews_130k])
reviews = reviews.reset_index(drop=True)
print(reviews.shape)
reviews

# %%
col = list(reviews.columns)
col

# %%
reviews_grp = reviews.groupby(col)
reviews_di = reviews_grp.groups
reviews_di

# %%
idx = [i[0] for i in reviews_di.values() if len(i) == 1]
reviews.loc[idx,:]

# %%
# reviews_150k.loc[[0]] == reviews_130k.loc[[0]]
# reviews_150k.loc[[129964]] == reviews_130k.loc[[129964]]

# %%
reviews_150k['region_2'].isnull().sum()

# %%
reviews_130k['region_2'].isnull().sum()

# %%
# 중복확인 #방법 2

reviews[reviews.duplicated(col)].shape[0]

# %%
# missingno 라이브러리 활용하여 null값 확인

import missingno as msno

msno.matrix(reviews_130k)

# %%
reviews_130k.describe()

# %%
reviews_130k.head()

# %%
reviews_130k.tail()

# %%
columns = reviews_130k.columns.tolist()

for i in range(0, len(columns)):
    print("***",columns[i],"***")
    print(reviews_130k[columns[i]].nunique(),'개')
    print(reviews_130k[columns[i]].value_counts(normalize=False))

# %%
# 중복값 삭제

print("Total number of examples: ", reviews_130k.shape[0])
print("Number of examples with the same title and description: ", reviews_130k[reviews_130k.duplicated(['description','title'])].shape[0])

# %%
reviews_130k=reviews_130k.drop_duplicates(['description','title'])
reviews=reviews_130k.reset_index(drop=True)

# %%
# 중복값 처리 후, 데이터 확인
reviews.shape

# %%
# 생산국 top 10

df = pd.DataFrame(reviews)['country'].value_counts().head(10).reset_index()
df.columns = ['country', 'count']
df

# %%
import matplotlib as mpl
mpl.rcParams['figure.dpi']= 100
from plotnine import * # R 시각화 라이브러리

# %%
(ggplot(df)
 + aes(x='country', y='count')
 + geom_col(fill='darkslateblue')
 + ggtitle("Countries with Most Reviews")
 + xlab('Country')
 + ylab('Reviews')
 + coord_flip()
 + theme(figure_size=(8, 6))
)
